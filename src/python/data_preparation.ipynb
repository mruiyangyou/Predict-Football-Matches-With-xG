# %% [markdown]
# # Baseline Model
#
# The notebook consits of three parts.
# * Import and install related packages
# * Data Perprocessing
# * Model Construction

# %%
# !pip install understat
# Out:
# Collecting understat
#   Downloading understat-0.1.7-py3-none-any.whl (10 kB)
# Collecting pytest-aiohttp==0.3.0
#   Downloading pytest_aiohttp-0.3.0-py3-none-any.whl (3.9 kB)
# Collecting pytest-cov==3.0.0
#   Downloading pytest_cov-3.0.0-py3-none-any.whl (20 kB)
# Collecting pytest-mock==3.6.0
#   Downloading pytest_mock-3.6.0-py3-none-any.whl (12 kB)
# Collecting aiohttp==3.7.4
#   Downloading aiohttp-3.7.4-cp38-cp38-macosx_10_14_x86_64.whl (648 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.3/648.3 kB 9.4 MB/s eta 0:00:0031m17.0 MB/s eta 0:00:01
# Collecting pytest==6.2.0
#   Downloading pytest-6.2.0-py3-none-any.whl (279 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.6/279.6 kB 4.1 MB/s eta 0:00:00m eta 0:00:01
# Collecting beautifulsoup4==4.9.3
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.8/115.8 kB 1.4 MB/s eta 0:00:0031m11.3 MB/s eta 0:00:01
# Collecting codecov==2.1.12
#   Downloading codecov-2.1.12-py2.py3-none-any.whl (16 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.7.4->understat) (19.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.7.4->understat) (4.0.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.7.4->understat) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.7.4->understat) (6.0.2)
# Requirement already satisfied: chardet<4.0,>=2.0 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from aiohttp==3.7.4->understat) (3.0.4)
# Requirement already satisfied: soupsieve>1.2 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4==4.9.3->understat) (2.0.1)
# Collecting coverage
#   Downloading coverage-6.5.0-cp38-cp38-macosx_10_9_x86_64.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 3.2 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: requests>=2.7.9 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from codecov==2.1.12->understat) (2.24.0)
# Requirement already satisfied: py>=1.8.2 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from pytest==6.2.0->understat) (1.9.0)
# Requirement already satisfied: packaging in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from pytest==6.2.0->understat) (21.3)
# Collecting iniconfig
#   Using cached iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Requirement already satisfied: toml in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from pytest==6.2.0->understat) (0.10.1)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from pytest==6.2.0->understat) (0.13.1)
# Collecting tomli
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.9->codecov==2.1.12->understat) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.9->codecov==2.1.12->understat) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.7.9->codecov==2.1.12->understat) (2020.6.20)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/marceloyou/opt/anaconda3/lib/python3.8/site-packages (from packaging->pytest==6.2.0->understat) (2.4.7)
# Installing collected packages: iniconfig, tomli, coverage, beautifulsoup4, async-timeout, pytest, codecov, aiohttp, pytest-mock, pytest-cov, pytest-aiohttp, understat
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.1
#     Uninstalling beautifulsoup4-4.9.1:
#       Successfully uninstalled beautifulsoup4-4.9.1
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 4.0.2
#     Uninstalling async-timeout-4.0.2:
#       Successfully uninstalled async-timeout-4.0.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 5.4.3
#     Uninstalling pytest-5.4.3:
#       Successfully uninstalled pytest-5.4.3
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.8.1
#     Uninstalling aiohttp-3.8.1:
#       Successfully uninstalled aiohttp-3.8.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-vision 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-vision 0.3.1 requires Pillow<8.4.0,>=8.3.0, but you have pillow 9.2.0 which is incompatible.
# autogluon-text 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-text 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-tabular 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-tabular 0.3.1 requires psutil<5.9,>=5.7.3, but you have psutil 5.9.2 which is incompatible.
# autogluon-tabular 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-mxnet 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-mxnet 0.3.1 requires Pillow<8.4.0,>=8.3.0, but you have pillow 9.2.0 which is incompatible.
# autogluon-mxnet 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-features 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-features 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# autogluon-extra 0.3.1 requires numpy<1.22,>=1.19, but you have numpy 1.18.5 which is incompatible.
# autogluon-extra 0.3.1 requires scikit-learn<0.25,>=0.23.2, but you have scikit-learn 1.0.2 which is incompatible.
# Successfully installed aiohttp-3.7.4 async-timeout-3.0.1 beautifulsoup4-4.9.3 codecov-2.1.12 coverage-6.5.0 iniconfig-1.1.1 pytest-6.2.0 pytest-aiohttp-0.3.0 pytest-cov-3.0.0 pytest-mock-3.6.0 tomli-2.0.1 understat-0.1.7

# %% [markdown]
# ## Install Pakcages

# %%
# !pip install nest-asyncio
# Out:
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.5.6-py3-none-any.whl (5.2 kB)
# Installing collected packages: nest-asyncio
# Successfully installed nest-asyncio-1.5.6

# %%
import asyncio
import json
import aiohttp
from understat import Understat
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import *
import nest_asyncio
nest_asyncio.apply()
# __import__('IPython').embed()

# %% [markdown]
# ## Loading and Prepare data from Understat
#
# I will choose my team Chelsea as an example. The prediction match results will use
# 1. xG(Predicted)
# 2. previous record
# 3. recent state(recent win within 5 games)
# 4. tactics(formation)
# 5. Player inside the squad(define by players recent performance(evaluation system))
# 6. Rank on the table
# 7. Coach and other
#
# <hr>
#
# While xG expectation will be predicted by
# 1. Previous goals against the team
# 2. Recent Goals(five games)
# 3. Player
# 4. Game Stats(recent five game pocession and shots)

# %% [markdown]
# ### xG data prapartion
#
# * accquire all data related to match such as result, time, goals
# * find the game statistics of the particular game(formation, shots, miss shots)
# * obtain the recent statistics and club state
# * num of players in top10 goal and assist rank

# %%
# Define some variable
team = 'Chelsea'
stats_interval = 5

# %% [markdown]
# #### Data Function

# %%
def get_match_result(team, season):
    async def main():
        async with aiohttp.ClientSession() as session:
            understat = Understat(session)
            team_stats = await understat.get_team_results(
                team,
                season
            )
            # return json.dumps(team_stats)
            return team_stats


    loop = asyncio.get_event_loop()
    data = loop.run_until_complete(main())
    return data

def get_playershot_data(match_id):
    async def main():
        async with aiohttp.ClientSession() as session:
            understat = Understat(session)
            players = await understat.get_match_shots(match_id)
            return players
    loop = asyncio.get_event_loop()
    players = loop.run_until_complete(main())
    return players

def get_player_data(match_id):
    async def main():
        async with aiohttp.ClientSession() as session:
            understat = Understat(session)
            players = await understat.get_match_players(match_id)
            return players

    loop = asyncio.get_event_loop()
    players = loop.run_until_complete(main())
    return players

def get_goal_rank(league, season, find_team, team = None):
    async def main():
        if find_team:

            async with aiohttp.ClientSession() as session:
                understat = Understat(session)
                players = await understat.get_league_players(
                    league,
                    season,
                    team_title = team
                )

               
        else:
            async with aiohttp.ClientSession() as session:
                understat = Understat(session)
                players = await understat.get_league_players(
                    league,
                    season
                )

        return players

    loop = asyncio.get_event_loop()
    rank = loop.run_until_complete(main())
    return rank

# %% [markdown]
# #### Data Processing Functions

# %%
def Constrcut_df_from_results(li):
    '''
    Parameter: li - List

    Return DataFrame

    Id - Game oid
    oppoenet - team name
    opponent_id - id of team name
    home - binary for whether in home(0:home, 1:away)
    result - win/draw/loss
    datatime - Game time
    xG - xG of chelsea
    xG_opponent - Xg of oppoenent
    '''

    col_name = 'id', 'oppenet', 'opponent_id', 'home', 'result', 'datetime', 'xG', 'num_of_score_goals', 'num_of_conced_goals'
    id, oppenet, opponent_id, home, result, datetime, xG,goal_score, goal_conced = [], [], [], [], [], [], [], [], []
    for game in li:
        id.append(game['id'])
        opo_side = 'a' if game['side'] == 'h' else 'h'
        oppenet.append(game[opo_side]['title'])
        opponent_id.append(game[opo_side]['id'])
        home.append(0 if game['side'] == 'h' else 1)
        result.append(game['result'])
        xG.append(game['xG'][game['side']])
        datetime.append(game['datetime'])
        goal_score.append(game['goals'][game['side']])
        goal_conced.append(game['goals'][opo_side])
    data_list = [id, oppenet, opponent_id, home, result, datetime, xG,goal_score, goal_conced]
    df = pd.DataFrame({col_name: col for col_name, col in zip(col_name, data_list)})
    return df

def num_of_shots(id, home):
    '''
    Parmeter:
    id - Game id
    home - whether the game is home or away
    players - player shot data 

    Return the number of shots and shots of opponent

    '''
    status = 'h' if home == 0 else 'a'
    players = get_playershot_data(id)
    return len(players[status])

# after merge data 
def get_stats_dict(league, season, type, n,find_team, team = None):
    data = get_goal_rank(league, season, find_team, team)
    data_dict = {x['player_name']: x[type] for x in data}
    sorted_data = sorted(data_dict.keys(), key= lambda x: int(data_dict[x]), reverse=True)[:n]
    return sorted_data
    
    
def get_player_stats(id_data, season):
    
    col_names = ['id', 'datetime', 'home', 'name', 'goal', 'assit', 'shot', 'rank_goal', 'rank_team_goal', 'rank_assist', 'rank_team_assist']
    res_df = pd.DataFrame(columns=col_names)
    for i in range(id_data.shape[0]):
        print(id_data.loc[i, 'id'])
        status = 'h' if id_data.loc[i, 'home'] == 0 else 'a'
        player_data = get_player_data(id_data.loc[i, 'id'])[status]
        match_data = get_playershot_data(id_data.loc[i, 'id'])[status]
        team = list(map(lambda x: player_data[x]['player'], player_data.keys()))
        df = pd.DataFrame(np.zeros((len(team),len(col_names))), columns=col_names)
        df['id'] = id_data.loc[i, 'id']
        df['status'] = status
        df['name'] = team

        for shot in match_data:
            df.loc[df['name'] == shot['player'], 'shot'] += 1
            if shot['result'] == 'Goal':
                df.loc[df['name'] == shot['player'], 'goal'] += 1
                df.loc[df['name'] == shot['player_assisted'],'assit'] += 1
            else:
                pass
        datetime  =  id_data.loc[i, 'datetime']
        df['datetime'] = datetime
        # start to fill the player columns
        # r
        league_goal_rank = get_stats_dict('epl', season, 'goals', 15, False)
        league_assit_rank = get_stats_dict('epl', season, 'assists', 15, False)
        team_goal_rank = get_stats_dict('epl', season, 'goals', 5, True, team)
        team_assit_rank = get_stats_dict('epl', season, 'goals', 5, True, team)
        
        def player_upgrade(x, list):
            return x+1 if x in list else x

        for col, li in zip(['rank_goal', 'rank_team_goal', 'rank_assist', 'rank_team_assist'], [league_goal_rank, league_assit_rank, 
           team_assit_rank, team_goal_rank]):
            df[col] = df[col].apply(lambda x: player_upgrade(x, li))

        res_df = pd.concat([res_df, df], axis = 0)

    return res_df

# %% [markdown]
# #### Example

# %%
data = get_match_result(team, 2018)

# %%
df = Constrcut_df_from_results(data)

# %%
df.head()
# Out:
#      id           oppenet opponent_id  home result             datetime  \
# 0  9200      Huddersfield         219     1      w  2018-08-11 17:00:00
# 1  9212           Arsenal          83     0      w  2018-08-18 19:30:00
# 2  9225  Newcastle United          86     1      w  2018-08-26 18:00:00
# 3  9231       Bournemouth          73     0      w  2018-09-01 14:00:00
# 4  9241           Cardiff         227     0      w  2018-09-15 14:00:00
#
#         xG num_of_score_goals num_of_conced_goals
# 0  2.31427                  3                   0
# 1  1.71799                  3                   2
# 2  1.49669                  2                   1
# 3  1.16408                  2                   0
# 4  2.67145                  4                   1

# %%
df['id']
# Out:
# 0     9200
# 1     9212
# 2     9225
# 3     9231
# 4     9241
# 5     9255
# 6     9264
# 7     9275
# 8     9277
# 9     9295
# 10    9305
# 11    9314
# 12    9323
# 13    9334
# 14    9339
# 15    9352
# 16    9366
# 17    9373
# 18    9377
# 19    9394
# 20    9403
# 21    9413
# 22    9426
# 23    9430
# 24    9443
# 25    9454
# 26    9474
# 27    9482
# 28    9494
# 29    9503
# 30    9514
# 31    9462
# 32    9525
# 33    9531
# 34    9543
# 35    9550
# 36    9563
# 37    9572
# Name: id, dtype: object

# %%
df['shots_attempt'] = df.apply(lambda x: num_of_shots(x['id'], x['home']), axis = 1)

# %%
df
# Out:
#       id                  oppenet opponent_id  home result  \
# 0   9200             Huddersfield         219     1      w
# 1   9212                  Arsenal          83     0      w
# 2   9225         Newcastle United          86     1      w
# 3   9231              Bournemouth          73     0      w
# 4   9241                  Cardiff         227     0      w
# 5   9255                 West Ham          81     1      d
# 6   9264                Liverpool          87     0      d
# 7   9275              Southampton          74     1      w
# 8   9277        Manchester United          89     0      d
# 9   9295                  Burnley          92     1      w
# 10  9305           Crystal Palace          78     0      w
# 11  9314                  Everton          72     0      d
# 12  9323                Tottenham          82     1      l
# 13  9334                   Fulham         228     0      w
# 14  9339  Wolverhampton Wanderers         229     1      l
# 15  9352          Manchester City          88     0      w
# 16  9366                 Brighton         220     1      w
# 17  9373                Leicester          75     0      l
# 18  9377                  Watford          90     1      w
# 19  9394           Crystal Palace          78     1      w
# 20  9403              Southampton          74     0      d
# 21  9413         Newcastle United          86     0      w
# 22  9426                  Arsenal          83     1      l
# 23  9430              Bournemouth          73     1      l
# 24  9443             Huddersfield         219     0      w
# 25  9454          Manchester City          88     1      l
# 26  9474                Tottenham          82     0      w
# 27  9482                   Fulham         228     1      w
# 28  9494  Wolverhampton Wanderers         229     0      d
# 29  9503                  Everton          72     1      l
# 30  9514                  Cardiff         227     1      w
# 31  9462                 Brighton         220     0      w
# 32  9525                 West Ham          81     0      w
# 33  9531                Liverpool          87     1      l
# 34  9543                  Burnley          92     0      d
# 35  9550        Manchester United          89     1      d
# 36  9563                  Watford          90     0      w
# 37  9572                Leicester          75     1      d
#
#                datetime        xG num_of_score_goals num_of_conced_goals  \
# 0   2018-08-11 17:00:00   2.31427                  3                   0
# 1   2018-08-18 19:30:00   1.71799                  3                   2
# 2   2018-08-26 18:00:00   1.49669                  2                   1
# 3   2018-09-01 14:00:00   1.16408                  2                   0
# 4   2018-09-15 14:00:00   2.67145                  4                   1
# 5   2018-09-23 12:30:00   1.88344                  0                   0
# 6   2018-09-29 16:30:00   1.77638                  1                   1
# 7   2018-10-07 13:15:00   3.54699                  3                   0
# 8   2018-10-20 11:30:00   2.21163                  2                   2
# 9   2018-10-28 12:30:00   3.01621                  4                   0
# 10  2018-11-04 16:00:00   1.88741                  3                   1
# 11  2018-11-11 14:15:00   1.16298                  0                   0
# 12  2018-11-24 17:30:00  0.962804                  1                   3
# 13  2018-12-02 12:00:00   2.17105                  2                   0
# 14  2018-12-05 19:45:00   1.10702                  1                   2
# 15  2018-12-08 17:30:00  0.526329                  2                   0
# 16  2018-12-16 13:30:00    1.6111                  2                   1
# 17  2018-12-22 15:00:00   2.40458                  0                   1
# 18  2018-12-26 19:30:00    2.1956                  2                   1
# 19  2018-12-30 12:00:00  0.741471                  1                   0
# 20  2019-01-02 19:45:00  0.850791                  0                   0
# 21  2019-01-12 17:30:00   1.32355                  2                   1
# 22  2019-01-19 17:30:00  0.755304                  0                   2
# 23  2019-01-30 19:45:00  0.718873                  0                   4
# 24  2019-02-02 15:00:00   2.94236                  5                   0
# 25  2019-02-10 16:00:00  0.901867                  0                   6
# 26  2019-02-27 20:00:00  0.625978                  2                   0
# 27  2019-03-03 14:05:00   1.53632                  2                   1
# 28  2019-03-10 14:05:00    1.0471                  1                   1
# 29  2019-03-17 16:30:00   1.24394                  0                   2
# 30  2019-03-31 13:05:00   2.07834                  2                   1
# 31  2019-04-03 19:45:00   3.12416                  3                   0
# 32  2019-04-08 20:00:00   2.23287                  2                   0
# 33  2019-04-14 16:30:00  0.873177                  0                   2
# 34  2019-04-22 20:00:00   1.28197                  2                   2
# 35  2019-04-28 16:30:00    1.6298                  1                   1
# 36  2019-05-05 13:00:00   2.96478                  3                   0
# 37  2019-05-12 14:00:00   1.26735                  0                   0
#
#     shots_attempt
# 0              13
# 1              24
# 2              15
# 3              24
# 4              18
# 5              17
# 6              10
# 7              21
# 8              21
# 9              24
# 10             15
# 11             15
# 12             13
# 13             16
# 14             17
# 15              8
# 16             10
# 17             17
# 18             10
# 19             12
# 20             17
# 21             10
# 22             13
# 23             11
# 24             23
# 25             12
# 26             11
# 27             20
# 28             22
# 29             16
# 30             21
# 31             17
# 32             16
# 33              6
# 34             22
# 35             16
# 36             19
# 37             14

# %%
df.to_csv('../../../data/Chelsea_2018.csv', index = None)

# %%
player_df = get_player_stats(df, season=2017)
# Out:
# 9200
# 9212
# 9225
# 9231
# 9241
# 9255
# 9264
# 9275
# 9277
# 9295
# 9305
# 9314
# 9323
# 9334
# 9339
# 9352
# 9366
# 9373
# 9377
# 9394
# 9403
# 9413
# 9426
# 9430
# 9443
# 9454
# 9474
# 9482
# 9494
# 9503
# 9514
# 9462
# 9525
# 9531
# 9543
# 9550
# 9563
# 9572

# %%
rank = get_goal_rank('epl', 2017)
rank
# Out:
# [{'id': '1250',
#   'player_name': 'Mohamed Salah',
#   'games': '36',
#   'time': '2954',
#   'goals': '32',
#   'xG': '25.136502970010042',
#   'assists': '10',
#   'xA': '8.344477602280676',
#   'shots': '143',
#   'key_passes': '62',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '31',
#   'npxG': '23.6141653098166',
#   'xGChain': '35.301465447992086',
#   'xGBuildup': '5.898578152060509'},
#  {'id': '647',
#   'player_name': 'Harry Kane',
#   'games': '37',
#   'time': '3094',
#   'goals': '30',
#   'xG': '26.859890587627888',
#   'assists': '2',
#   'xA': '3.8204412199556828',
#   'shots': '183',
#   'key_passes': '34',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Tottenham',
#   'npg': '28',
#   'npxG': '24.576384104788303',
#   'xGChain': '28.51526607386768',
#   'xGBuildup': '7.9616343677043915'},
#  {'id': '619',
#   'player_name': 'Sergio Agüero',
#   'games': '25',
#   'time': '1985',
#   'goals': '21',
#   'xG': '18.56861797720194',
#   'assists': '6',
#   'xA': '6.533229699358344',
#   'shots': '95',
#   'key_passes': '39',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '17',
#   'npxG': '15.523942567408085',
#   'xGChain': '23.707814872264862',
#   'xGBuildup': '7.512718818150461'},
#  {'id': '755',
#   'player_name': 'Jamie Vardy',
#   'games': '37',
#   'time': '3269',
#   'goals': '20',
#   'xG': '15.266967067494988',
#   'assists': '1',
#   'xA': '3.6308264825493097',
#   'shots': '70',
#   'key_passes': '33',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F',
#   'team_title': 'Leicester',
#   'npg': '15',
#   'npxG': '10.699990747496486',
#   'xGChain': '15.584633570164442',
#   'xGBuildup': '1.9777417127043009'},
#  {'id': '618',
#   'player_name': 'Raheem Sterling',
#   'games': '33',
#   'time': '2594',
#   'goals': '18',
#   'xG': '18.829967338591814',
#   'assists': '11',
#   'xA': '8.844115875661373',
#   'shots': '87',
#   'key_passes': '55',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '17',
#   'npxG': '18.06879848614335',
#   'xGChain': '33.65671702474356',
#   'xGBuildup': '12.149656612426043'},
#  {'id': '594',
#   'player_name': 'Romelu Lukaku',
#   'games': '34',
#   'time': '2869',
#   'goals': '16',
#   'xG': '15.468220829963684',
#   'assists': '7',
#   'xA': '5.473206410184503',
#   'shots': '86',
#   'key_passes': '33',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester United',
#   'npg': '16',
#   'npxG': '14.707051992416382',
#   'xGChain': '24.643031921237707',
#   'xGBuildup': '7.161954903975129'},
#  {'id': '482',
#   'player_name': 'Roberto Firmino',
#   'games': '37',
#   'time': '2814',
#   'goals': '15',
#   'xG': '10.763707412406802',
#   'assists': '7',
#   'xA': '7.67842498794198',
#   'shots': '84',
#   'key_passes': '56',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '14',
#   'npxG': '10.002538589760661',
#   'xGChain': '27.837451616302133',
#   'xGBuildup': '12.625402934849262'},
#  {'id': '3277',
#   'player_name': 'Alexandre Lacazette',
#   'games': '32',
#   'time': '2235',
#   'goals': '14',
#   'xG': '13.831241022795439',
#   'assists': '4',
#   'xA': '4.839554825797677',
#   'shots': '67',
#   'key_passes': '36',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '12',
#   'npxG': '12.308903332799673',
#   'xGChain': '20.898551642894745',
#   'xGBuildup': '6.228630402125418'},
#  {'id': '5543',
#   'player_name': 'Gabriel Jesus',
#   'games': '29',
#   'time': '1692',
#   'goals': '13',
#   'xG': '15.366188988089561',
#   'assists': '3',
#   'xA': '2.3076753597706556',
#   'shots': '55',
#   'key_passes': '18',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '13',
#   'npxG': '13.843851312994957',
#   'xGChain': '20.56147326901555',
#   'xGBuildup': '6.5146970227360725'},
#  {'id': '453',
#   'player_name': 'Son Heung-Min',
#   'games': '37',
#   'time': '2315',
#   'goals': '12',
#   'xG': '11.021603035740554',
#   'assists': '6',
#   'xA': '6.592509059235454',
#   'shots': '75',
#   'key_passes': '38',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Tottenham',
#   'npg': '12',
#   'npxG': '11.021603035740554',
#   'xGChain': '22.61797249224037',
#   'xGBuildup': '6.259736826643348'},
#  {'id': '701',
#   'player_name': 'Eden Hazard',
#   'games': '34',
#   'time': '2451',
#   'goals': '12',
#   'xG': '8.212463462725282',
#   'assists': '4',
#   'xA': '7.303086698055267',
#   'shots': '71',
#   'key_passes': '84',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '10',
#   'npxG': '6.690125757828355',
#   'xGChain': '19.691347554326057',
#   'xGBuildup': '9.2949508279562'},
#  {'id': '750',
#   'player_name': 'Riyad Mahrez',
#   'games': '36',
#   'time': '2977',
#   'goals': '12',
#   'xG': '6.61353119648993',
#   'assists': '10',
#   'xA': '7.55104211345315',
#   'shots': '74',
#   'key_passes': '57',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Leicester',
#   'npg': '12',
#   'npxG': '6.61353119648993',
#   'xGChain': '15.855960881337523',
#   'xGBuildup': '6.466544289141893'},
#  {'id': '882',
#   'player_name': 'Glenn Murray',
#   'games': '35',
#   'time': '2204',
#   'goals': '12',
#   'xG': '12.380600898526609',
#   'assists': '0',
#   'xA': '1.2383797569200397',
#   'shots': '52',
#   'key_passes': '16',
#   'yellow_cards': '9',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Brighton',
#   'npg': '8',
#   'npxG': '7.813587754033506',
#   'xGChain': '8.483370034955442',
#   'xGBuildup': '1.6577221099287271'},
#  {'id': '865',
#   'player_name': 'Marko Arnautovic',
#   'games': '31',
#   'time': '2343',
#   'goals': '11',
#   'xG': '9.801481921225786',
#   'assists': '6',
#   'xA': '4.447798945009708',
#   'shots': '71',
#   'key_passes': '34',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'West Ham',
#   'npg': '11',
#   'npxG': '9.801481921225786',
#   'xGChain': '13.037374045699835',
#   'xGBuildup': '2.6873114239424467'},
#  {'id': '1804',
#   'player_name': 'Álvaro Morata',
#   'games': '31',
#   'time': '2069',
#   'goals': '11',
#   'xG': '13.904703490436077',
#   'assists': '6',
#   'xA': '3.5832394156605005',
#   'shots': '79',
#   'key_passes': '36',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '11',
#   'npxG': '13.904703490436077',
#   'xGChain': '17.912706471979618',
#   'xGBuildup': '2.9470131658017635'},
#  {'id': '318',
#   'player_name': 'Pierre-Emerick Aubameyang',
#   'games': '13',
#   'time': '1056',
#   'goals': '10',
#   'xG': '9.174377799034119',
#   'assists': '4',
#   'xA': '1.2641484700143337',
#   'shots': '31',
#   'key_passes': '13',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal',
#   'npg': '9',
#   'npxG': '7.652040150016546',
#   'xGChain': '10.671040249988437',
#   'xGBuildup': '2.366455566138029'},
#  {'id': '337',
#   'player_name': 'Leroy Sané',
#   'games': '32',
#   'time': '2421',
#   'goals': '10',
#   'xG': '6.24107522983104',
#   'assists': '15',
#   'xA': '9.048876539804041',
#   'shots': '56',
#   'key_passes': '58',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Manchester City',
#   'npg': '10',
#   'npxG': '6.24107522983104',
#   'xGChain': '19.683995423838496',
#   'xGBuildup': '11.898687457665801'},
#  {'id': '629',
#   'player_name': 'Wayne Rooney',
#   'games': '31',
#   'time': '2301',
#   'goals': '10',
#   'xG': '8.905443045310676',
#   'assists': '2',
#   'xA': '2.281340353190899',
#   'shots': '45',
#   'key_passes': '34',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Everton',
#   'npg': '7',
#   'npxG': '4.338429889641702',
#   'xGChain': '8.366078531369567',
#   'xGBuildup': '4.465429299511015'},
#  {'id': '646',
#   'player_name': 'Christian Eriksen',
#   'games': '37',
#   'time': '3239',
#   'goals': '10',
#   'xG': '7.245938941836357',
#   'assists': '10',
#   'xA': '11.893049443140626',
#   'shots': '96',
#   'key_passes': '95',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Tottenham',
#   'npg': '10',
#   'npxG': '7.245938941836357',
#   'xGChain': '27.00611260905862',
#   'xGBuildup': '15.511445418931544'},
#  {'id': '838',
#   'player_name': 'Sadio Mané',
#   'games': '29',
#   'time': '2230',
#   'goals': '10',
#   'xG': '11.518153592944145',
#   'assists': '7',
#   'xA': '5.250221345573664',
#   'shots': '70',
#   'key_passes': '49',
#   'yellow_cards': '3',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '10',
#   'npxG': '11.518153592944145',
#   'xGChain': '21.158787678927183',
#   'xGBuildup': '6.351253589615226'},
#  {'id': '4456',
#   'player_name': 'Chris Wood',
#   'games': '24',
#   'time': '1639',
#   'goals': '10',
#   'xG': '7.639506213366985',
#   'assists': '1',
#   'xA': '0.6027078554034233',
#   'shots': '40',
#   'key_passes': '11',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Burnley',
#   'npg': '10',
#   'npxG': '7.639506213366985',
#   'xGChain': '7.594883928075433',
#   'xGBuildup': '1.022325236350298'},
#  {'id': '5549',
#   'player_name': 'Luka Milivojevic',
#   'games': '36',
#   'time': '3087',
#   'goals': '10',
#   'xG': '7.874588200822473',
#   'assists': '1',
#   'xA': '1.2642450630664825',
#   'shots': '42',
#   'key_passes': '21',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Crystal Palace',
#   'npg': '3',
#   'npxG': '1.785385170020163',
#   'xGChain': '8.746629861183465',
#   'xGBuildup': '8.064285509288311'},
#  {'id': '498',
#   'player_name': 'Alexis Sánchez',
#   'games': '31',
#   'time': '2562',
#   'goals': '9',
#   'xG': '11.422602553851902',
#   'assists': '6',
#   'xA': '7.917655121535063',
#   'shots': '88',
#   'key_passes': '77',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal,Manchester United',
#   'npg': '8',
#   'npxG': '9.900264878757298',
#   'xGChain': '22.282545514404774',
#   'xGBuildup': '9.066157701425254'},
#  {'id': '522',
#   'player_name': 'Wilfried Zaha',
#   'games': '29',
#   'time': '2551',
#   'goals': '9',
#   'xG': '9.735278444364667',
#   'assists': '3',
#   'xA': '5.296256110072136',
#   'shots': '64',
#   'key_passes': '53',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '9',
#   'npxG': '9.735278444364667',
#   'xGChain': '16.14480810239911',
#   'xGBuildup': '3.00129756052047'},
#  {'id': '553',
#   'player_name': 'Anthony Martial',
#   'games': '30',
#   'time': '1589',
#   'goals': '9',
#   'xG': '6.301933970302343',
#   'assists': '5',
#   'xA': '5.435461966320872',
#   'shots': '49',
#   'key_passes': '33',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '8',
#   'npxG': '5.540765132755041',
#   'xGChain': '13.706218170002103',
#   'xGBuildup': '5.228315457701683'},
#  {'id': '617',
#   'player_name': 'David Silva',
#   'games': '29',
#   'time': '2442',
#   'goals': '9',
#   'xG': '9.241164376959205',
#   'assists': '11',
#   'xA': '8.82798683270812',
#   'shots': '54',
#   'key_passes': '61',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '9',
#   'npxG': '9.241164376959205',
#   'xGChain': '30.25495454110205',
#   'xGBuildup': '18.98137961141765'},
#  {'id': '645',
#   'player_name': 'Dele Alli',
#   'games': '36',
#   'time': '2991',
#   'goals': '9',
#   'xG': '10.104957189410925',
#   'assists': '10',
#   'xA': '8.836119271814823',
#   'shots': '69',
#   'key_passes': '64',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Tottenham',
#   'npg': '9',
#   'npxG': '10.104957189410925',
#   'xGChain': '23.885979956015944',
#   'xGBuildup': '8.14344278536737'},
#  {'id': '4422',
#   'player_name': 'Ashley Barnes',
#   'games': '36',
#   'time': '2143',
#   'goals': '9',
#   'xG': '6.560562789440155',
#   'assists': '0',
#   'xA': '1.5027274526655674',
#   'shots': '61',
#   'key_passes': '17',
#   'yellow_cards': '10',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Burnley',
#   'npg': '9',
#   'npxG': '6.560562789440155',
#   'xGChain': '8.709057147614658',
#   'xGBuildup': '1.9067803481593728'},
#  {'id': '191',
#   'player_name': 'Chicharito',
#   'games': '28',
#   'time': '1524',
#   'goals': '8',
#   'xG': '5.248028546571732',
#   'assists': '0',
#   'xA': '1.422036468051374',
#   'shots': '29',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '8',
#   'npxG': '5.248028546571732',
#   'xGChain': '6.960864821448922',
#   'xGBuildup': '1.803986500017345'},
#  {'id': '447',
#   'player_name': 'Kevin De Bruyne',
#   'games': '37',
#   'time': '3103',
#   'goals': '8',
#   'xG': '5.4017304321751',
#   'assists': '16',
#   'xA': '13.101720079779625',
#   'shots': '93',
#   'key_passes': '105',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '8',
#   'npxG': '5.4017304321751',
#   'xGChain': '33.50091540813446',
#   'xGBuildup': '22.899963654577732'},
#  {'id': '465',
#   'player_name': 'Joshua King',
#   'games': '33',
#   'time': '2458',
#   'goals': '8',
#   'xG': '6.555599365383387',
#   'assists': '3',
#   'xA': '4.888207009062171',
#   'shots': '51',
#   'key_passes': '38',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Bournemouth',
#   'npg': '6',
#   'npxG': '5.033261656761169',
#   'xGChain': '9.640528094954789',
#   'xGBuildup': '3.6070545027032495'},
#  {'id': '468',
#   'player_name': 'Callum Wilson',
#   'games': '28',
#   'time': '2007',
#   'goals': '8',
#   'xG': '7.619610041379929',
#   'assists': '2',
#   'xA': '1.5524410009384155',
#   'shots': '54',
#   'key_passes': '18',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Bournemouth',
#   'npg': '8',
#   'npxG': '7.619610041379929',
#   'xGChain': '9.413971451111138',
#   'xGBuildup': '2.697103791870177'},
#  {'id': '558',
#   'player_name': 'Jesse Lingard',
#   'games': '33',
#   'time': '1836',
#   'goals': '8',
#   'xG': '8.048349030315876',
#   'assists': '5',
#   'xA': '3.5819818507879972',
#   'shots': '56',
#   'key_passes': '26',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '8',
#   'npxG': '8.048349030315876',
#   'xGChain': '13.909841664135456',
#   'xGBuildup': '5.560849579051137'},
#  {'id': '599',
#   'player_name': 'Oumar Niasse',
#   'games': '22',
#   'time': '1075',
#   'goals': '8',
#   'xG': '7.417298145592213',
#   'assists': '2',
#   'xA': '1.54713324457407',
#   'shots': '37',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '8',
#   'npxG': '7.417298145592213',
#   'xGChain': '9.197526078671217',
#   'xGBuildup': '1.3837399259209633'},
#  {'id': '770',
#   'player_name': 'Ayoze Pérez',
#   'games': '36',
#   'time': '2502',
#   'goals': '8',
#   'xG': '6.864802069962025',
#   'assists': '5',
#   'xA': '5.451955586671829',
#   'shots': '60',
#   'key_passes': '36',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Newcastle United',
#   'npg': '8',
#   'npxG': '6.864802069962025',
#   'xGChain': '14.1159591935575',
#   'xGBuildup': '6.333310326561332'},
#  {'id': '888',
#   'player_name': 'Xherdan Shaqiri',
#   'games': '36',
#   'time': '3066',
#   'goals': '8',
#   'xG': '4.985688297078013',
#   'assists': '7',
#   'xA': '6.87552744615823',
#   'shots': '69',
#   'key_passes': '76',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Stoke',
#   'npg': '8',
#   'npxG': '4.22451944462955',
#   'xGChain': '11.416415916755795',
#   'xGBuildup': '5.910622897557914'},
#  {'id': '239',
#   'player_name': 'Pascal Groß',
#   'games': '38',
#   'time': '2979',
#   'goals': '7',
#   'xG': '3.335027128458023',
#   'assists': '8',
#   'xA': '8.656005831435323',
#   'shots': '43',
#   'key_passes': '81',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '6',
#   'npxG': '2.5738582983613014',
#   'xGChain': '12.21007040143013',
#   'xGBuildup': '5.4259272236377'},
#  {'id': '488',
#   'player_name': 'Philippe Coutinho',
#   'games': '14',
#   'time': '1132',
#   'goals': '7',
#   'xG': '3.6399389542639256',
#   'assists': '6',
#   'xA': '4.951587982475758',
#   'shots': '54',
#   'key_passes': '40',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Liverpool',
#   'npg': '7',
#   'npxG': '3.6399389542639256',
#   'xGChain': '9.052257478237152',
#   'xGBuildup': '3.7090023662894964'},
#  {'id': '502',
#   'player_name': 'Olivier Giroud',
#   'games': '29',
#   'time': '953',
#   'goals': '7',
#   'xG': '7.604713529348373',
#   'assists': '1',
#   'xA': '3.0130643099546432',
#   'shots': '47',
#   'key_passes': '20',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Arsenal,Chelsea',
#   'npg': '7',
#   'npxG': '7.604713529348373',
#   'xGChain': '10.695791564881802',
#   'xGBuildup': '1.6444561406970024'},
#  {'id': '504',
#   'player_name': 'Aaron Ramsey',
#   'games': '24',
#   'time': '1849',
#   'goals': '7',
#   'xG': '6.840767364948988',
#   'assists': '8',
#   'xA': '5.922472320497036',
#   'shots': '56',
#   'key_passes': '28',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Arsenal',
#   'npg': '7',
#   'npxG': '6.840767364948988',
#   'xGChain': '19.13112424314022',
#   'xGBuildup': '11.193582858890295'},
#  {'id': '556',
#   'player_name': 'Marcus Rashford',
#   'games': '35',
#   'time': '1792',
#   'goals': '7',
#   'xG': '5.530901059508324',
#   'assists': '5',
#   'xA': '4.597065225243568',
#   'shots': '62',
#   'key_passes': '22',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '7',
#   'npxG': '5.530901059508324',
#   'xGChain': '10.888660445809364',
#   'xGBuildup': '2.578550947830081'},
#  {'id': '672',
#   'player_name': 'Jordan Ayew',
#   'games': '36',
#   'time': '2862',
#   'goals': '7',
#   'xG': '6.851809272542596',
#   'assists': '2',
#   'xA': '1.9186684098094702',
#   'shots': '65',
#   'key_passes': '16',
#   'yellow_cards': '2',
#   'red_cards': '1',
#   'position': 'F M S',
#   'team_title': 'Swansea',
#   'npg': '6',
#   'npxG': '6.0906404396519065',
#   'xGChain': '8.016540210694075',
#   'xGBuildup': '1.894832988269627'},
#  {'id': '813',
#   'player_name': 'Salomón Rondón',
#   'games': '36',
#   'time': '2781',
#   'goals': '7',
#   'xG': '6.871560767292976',
#   'assists': '3',
#   'xA': '2.6148639917373657',
#   'shots': '78',
#   'key_passes': '23',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'West Bromwich Albion',
#   'npg': '7',
#   'npxG': '6.871560767292976',
#   'xGChain': '10.665166744962335',
#   'xGBuildup': '3.4010699428617954'},
#  {'id': '844',
#   'player_name': 'Jay Rodriguez',
#   'games': '37',
#   'time': '2845',
#   'goals': '7',
#   'xG': '7.642788367345929',
#   'assists': '1',
#   'xA': '1.8346650339663029',
#   'shots': '69',
#   'key_passes': '21',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'West Bromwich Albion',
#   'npg': '6',
#   'npxG': '6.881619529798627',
#   'xGChain': '8.146990897133946',
#   'xGBuildup': '1.5642688274383545'},
#  {'id': '848',
#   'player_name': 'Charlie Austin',
#   'games': '24',
#   'time': '1023',
#   'goals': '7',
#   'xG': '7.720574729144573',
#   'assists': '0',
#   'xA': '0.6937102861702442',
#   'shots': '47',
#   'key_passes': '4',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Southampton',
#   'npg': '6',
#   'npxG': '6.959405891597271',
#   'xGChain': '6.5175684886053205',
#   'xGBuildup': '1.2118305014446378'},
#  {'id': '1621',
#   'player_name': 'Marcos Alonso',
#   'games': '33',
#   'time': '2869',
#   'goals': '7',
#   'xG': '4.369033532217145',
#   'assists': '2',
#   'xA': '3.0571557134389877',
#   'shots': '65',
#   'key_passes': '34',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Chelsea',
#   'npg': '7',
#   'npxG': '4.369033532217145',
#   'xGChain': '12.986705735325813',
#   'xGBuildup': '8.145295701920986'},
#  {'id': '1726',
#   'player_name': 'Abdoulaye Doucouré',
#   'games': '37',
#   'time': '3326',
#   'goals': '7',
#   'xG': '3.1060853991657495',
#   'assists': '3',
#   'xA': '2.393647343851626',
#   'shots': '46',
#   'key_passes': '40',
#   'yellow_cards': '10',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Watford',
#   'npg': '7',
#   'npxG': '3.1060853991657495',
#   'xGChain': '11.492404110729694',
#   'xGBuildup': '7.35497585311532'},
#  {'id': '3800',
#   'player_name': 'Steve Mounie',
#   'games': '28',
#   'time': '1850',
#   'goals': '7',
#   'xG': '5.80149868875742',
#   'assists': '1',
#   'xA': '1.6073057148605585',
#   'shots': '49',
#   'key_passes': '16',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Huddersfield',
#   'npg': '7',
#   'npxG': '5.80149868875742',
#   'xGChain': '7.001166325062513',
#   'xGBuildup': '1.809567122720182'},
#  {'id': '700',
#   'player_name': 'Willian',
#   'games': '36',
#   'time': '1872',
#   'goals': '6',
#   'xG': '5.983236312866211',
#   'assists': '7',
#   'xA': '6.169512925669551',
#   'shots': '54',
#   'key_passes': '62',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '5',
#   'npxG': '5.222104266285896',
#   'xGChain': '12.889175640419126',
#   'xGBuildup': '5.100902387872338'},
#  {'id': '743',
#   'player_name': 'Dwight Gayle',
#   'games': '35',
#   'time': '1968',
#   'goals': '6',
#   'xG': '9.672671845182776',
#   'assists': '3',
#   'xA': '2.3920687939971685',
#   'shots': '57',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Newcastle United',
#   'npg': '6',
#   'npxG': '9.672671845182776',
#   'xGChain': '11.06782172061503',
#   'xGBuildup': '1.8391507137566805'},
#  {'id': '754',
#   'player_name': 'Shinji Okazaki',
#   'games': '27',
#   'time': '1340',
#   'goals': '6',
#   'xG': '7.492760078981519',
#   'assists': '2',
#   'xA': '1.8460093941539526',
#   'shots': '28',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Leicester',
#   'npg': '6',
#   'npxG': '7.492760078981519',
#   'xGChain': '8.057245753705502',
#   'xGBuildup': '1.1135968547314405'},
#  {'id': '840',
#   'player_name': 'Dusan Tadic',
#   'games': '36',
#   'time': '2854',
#   'goals': '6',
#   'xG': '5.660930041223764',
#   'assists': '3',
#   'xA': '6.163578130304813',
#   'shots': '40',
#   'key_passes': '59',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Southampton',
#   'npg': '5',
#   'npxG': '4.899761218577623',
#   'xGChain': '14.321497920900583',
#   'xGBuildup': '4.3436110727488995'},
#  {'id': '868',
#   'player_name': 'Mame Biram Diouf',
#   'games': '35',
#   'time': '2609',
#   'goals': '6',
#   'xG': '7.491201035678387',
#   'assists': '2',
#   'xA': '2.1150797703303397',
#   'shots': '58',
#   'key_passes': '20',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Stoke',
#   'npg': '6',
#   'npxG': '7.491201035678387',
#   'xGChain': '8.712970631197095',
#   'xGBuildup': '1.5370230674743652'},
#  {'id': '1740',
#   'player_name': 'Paul Pogba',
#   'games': '27',
#   'time': '2158',
#   'goals': '6',
#   'xG': '7.813678246922791',
#   'assists': '10',
#   'xA': '4.590671516954899',
#   'shots': '76',
#   'key_passes': '39',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '6',
#   'npxG': '7.813678246922791',
#   'xGChain': '16.820827029645443',
#   'xGBuildup': '8.208943894132972'},
#  {'id': '3635',
#   'player_name': 'Bernardo Silva',
#   'games': '35',
#   'time': '1500',
#   'goals': '6',
#   'xG': '4.5274060908705',
#   'assists': '4',
#   'xA': '3.0583887062966824',
#   'shots': '25',
#   'key_passes': '30',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Manchester City',
#   'npg': '6',
#   'npxG': '4.5274060908705',
#   'xGChain': '15.460781294852495',
#   'xGBuildup': '9.751076772809029'},
#  {'id': '6038',
#   'player_name': 'Laurent Depoitre',
#   'games': '33',
#   'time': '1794',
#   'goals': '6',
#   'xG': '3.591188936494291',
#   'assists': '1',
#   'xA': '1.3660858180373907',
#   'shots': '24',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Huddersfield',
#   'npg': '6',
#   'npxG': '3.591188936494291',
#   'xGChain': '4.533495036885142',
#   'xGBuildup': '1.0141412885859609'},
#  {'id': '339',
#   'player_name': 'Eric Maxim Choupo-Moting',
#   'games': '30',
#   'time': '2257',
#   'goals': '5',
#   'xG': '6.289976932108402',
#   'assists': '5',
#   'xA': '3.226308550685644',
#   'shots': '60',
#   'key_passes': '20',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Stoke',
#   'npg': '5',
#   'npxG': '6.289976932108402',
#   'xGChain': '9.28493205551058',
#   'xGBuildup': '2.2019113171845675'},
#  {'id': '463',
#   'player_name': 'Junior Stanislas',
#   'games': '19',
#   'time': '1313',
#   'goals': '5',
#   'xG': '3.831800527870655',
#   'assists': '2',
#   'xA': '1.9147691372781992',
#   'shots': '44',
#   'key_passes': '23',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Bournemouth',
#   'npg': '4',
#   'npxG': '3.070631690323353',
#   'xGChain': '5.264173872768879',
#   'xGBuildup': '1.8925352990627289'},
#  {'id': '495',
#   'player_name': 'Nacho Monreal',
#   'games': '28',
#   'time': '2246',
#   'goals': '5',
#   'xG': '1.9025151077657938',
#   'assists': '2',
#   'xA': '3.0137278269976377',
#   'shots': '21',
#   'key_passes': '13',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Arsenal',
#   'npg': '5',
#   'npxG': '1.9025151077657938',
#   'xGChain': '10.20766700990498',
#   'xGBuildup': '8.551960686221719'},
#  {'id': '501',
#   'player_name': 'Danny Welbeck',
#   'games': '28',
#   'time': '1169',
#   'goals': '5',
#   'xG': '5.722649244591594',
#   'assists': '2',
#   'xA': '1.3699026852846146',
#   'shots': '32',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal',
#   'npg': '5',
#   'npxG': '5.722649244591594',
#   'xGChain': '8.678983869031072',
#   'xGBuildup': '2.5617743469774723'},
#  {'id': '535',
#   'player_name': 'Manuel Lanzini',
#   'games': '27',
#   'time': '2054',
#   'goals': '5',
#   'xG': '3.833089454099536',
#   'assists': '6',
#   'xA': '3.734414921142161',
#   'shots': '44',
#   'key_passes': '41',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'West Ham',
#   'npg': '5',
#   'npxG': '3.071920631453395',
#   'xGChain': '9.272790788672864',
#   'xGBuildup': '5.11701469309628'},
#  {'id': '574',
#   'player_name': 'Troy Deeney',
#   'games': '29',
#   'time': '1832',
#   'goals': '5',
#   'xG': '7.1495265662670135',
#   'assists': '2',
#   'xA': '2.3760475926101208',
#   'shots': '36',
#   'key_passes': '26',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'Watford',
#   'npg': '2',
#   'npxG': '3.343682344071567',
#   'xGChain': '7.171732102520764',
#   'xGBuildup': '2.765413555316627'},
#  {'id': '614',
#   'player_name': 'Fernandinho',
#   'games': '34',
#   'time': '2890',
#   'goals': '5',
#   'xG': '2.466341163031757',
#   'assists': '3',
#   'xA': '2.8430620953440666',
#   'shots': '47',
#   'key_passes': '21',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '5',
#   'npxG': '2.466341163031757',
#   'xGChain': '25.39007394015789',
#   'xGBuildup': '22.23768274858594'},
#  {'id': '633',
#   'player_name': 'James McArthur',
#   'games': '33',
#   'time': '2440',
#   'goals': '5',
#   'xG': '4.228801898658276',
#   'assists': '1',
#   'xA': '2.0599370086565614',
#   'shots': '30',
#   'key_passes': '20',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Crystal Palace',
#   'npg': '5',
#   'npxG': '4.228801898658276',
#   'xGChain': '10.530749277211726',
#   'xGBuildup': '6.216755921021104'},
#  {'id': '702',
#   'player_name': 'Tammy Abraham',
#   'games': '31',
#   'time': '1706',
#   'goals': '5',
#   'xG': '6.159959049895406',
#   'assists': '1',
#   'xA': '1.4442990459501743',
#   'shots': '42',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Swansea',
#   'npg': '5',
#   'npxG': '6.159959049895406',
#   'xGChain': '7.5733319371938705',
#   'xGBuildup': '1.303047126159072'},
#  {'id': '730',
#   'player_name': 'Patrick van Aanholt',
#   'games': '28',
#   'time': '2184',
#   'goals': '5',
#   'xG': '3.393267946317792',
#   'assists': '1',
#   'xA': '2.45547766238451',
#   'shots': '33',
#   'key_passes': '18',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Crystal Palace',
#   'npg': '5',
#   'npxG': '3.393267946317792',
#   'xGChain': '7.4307730393484235',
#   'xGBuildup': '4.098446818999946'},
#  {'id': '872',
#   'player_name': 'Peter Crouch',
#   'games': '31',
#   'time': '1532',
#   'goals': '5',
#   'xG': '4.215646747499704',
#   'assists': '2',
#   'xA': '3.1475231647491455',
#   'shots': '23',
#   'key_passes': '21',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Stoke',
#   'npg': '5',
#   'npxG': '4.215646747499704',
#   'xGChain': '7.294581176713109',
#   'xGBuildup': '1.3116849400103092'},
#  {'id': '1383',
#   'player_name': 'Manolo Gabbiadini',
#   'games': '28',
#   'time': '1056',
#   'goals': '5',
#   'xG': '2.5225432254374027',
#   'assists': '0',
#   'xA': '0.5467097796499729',
#   'shots': '22',
#   'key_passes': '7',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Southampton',
#   'npg': '4',
#   'npxG': '1.761374358087778',
#   'xGChain': '3.041186712682247',
#   'xGBuildup': '1.450882963836193'},
#  {'id': '1660',
#   'player_name': 'Andre Gray',
#   'games': '31',
#   'time': '1486',
#   'goals': '5',
#   'xG': '7.001011338084936',
#   'assists': '2',
#   'xA': '2.318395335227251',
#   'shots': '34',
#   'key_passes': '17',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Watford',
#   'npg': '5',
#   'npxG': '7.001011338084936',
#   'xGChain': '10.135452036745846',
#   'xGBuildup': '1.7271905662491918'},
#  {'id': '1683',
#   'player_name': 'Ryan Fraser',
#   'games': '26',
#   'time': '2016',
#   'goals': '5',
#   'xG': '1.9803195875138044',
#   'assists': '3',
#   'xA': '2.7351528238505125',
#   'shots': '31',
#   'key_passes': '43',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Bournemouth',
#   'npg': '5',
#   'npxG': '1.9803195875138044',
#   'xGChain': '6.385161653161049',
#   'xGBuildup': '3.3411665204912424'},
#  {'id': '1723',
#   'player_name': 'Roberto Pereyra',
#   'games': '32',
#   'time': '1618',
#   'goals': '5',
#   'xG': '3.9139174856245518',
#   'assists': '2',
#   'xA': '2.6691006161272526',
#   'shots': '33',
#   'key_passes': '23',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Watford',
#   'npg': '5',
#   'npxG': '3.9139174856245518',
#   'xGChain': '7.717018766328692',
#   'xGBuildup': '2.8904048893600702'},
#  {'id': '6026',
#   'player_name': 'Richarlison',
#   'games': '38',
#   'time': '2832',
#   'goals': '5',
#   'xG': '10.662872670218349',
#   'assists': '4',
#   'xA': '3.807929993607104',
#   'shots': '95',
#   'key_passes': '26',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Watford',
#   'npg': '5',
#   'npxG': '10.662872670218349',
#   'xGChain': '14.732109196484089',
#   'xGBuildup': '2.519990134984255'},
#  {'id': '6231',
#   'player_name': 'José Izquierdo',
#   'games': '32',
#   'time': '1998',
#   'goals': '5',
#   'xG': '3.6233118548989296',
#   'assists': '3',
#   'xA': '2.325506180524826',
#   'shots': '52',
#   'key_passes': '21',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Brighton',
#   'npg': '5',
#   'npxG': '3.6233118548989296',
#   'xGChain': '7.212833768688142',
#   'xGBuildup': '3.131934610195458'},
#  {'id': '6477',
#   'player_name': 'Cenk Tosun',
#   'games': '14',
#   'time': '998',
#   'goals': '5',
#   'xG': '3.1851306576281786',
#   'assists': '0',
#   'xA': '1.7238558437675238',
#   'shots': '19',
#   'key_passes': '15',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Everton',
#   'npg': '5',
#   'npxG': '3.1851306576281786',
#   'xGChain': '5.5636201202869415',
#   'xGBuildup': '1.1438307538628578'},
#  {'id': '314',
#   'player_name': 'Ilkay Gündogan',
#   'games': '30',
#   'time': '1504',
#   'goals': '4',
#   'xG': '3.583664696663618',
#   'assists': '1',
#   'xA': '2.3488316610455513',
#   'shots': '35',
#   'key_passes': '21',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester City',
#   'npg': '3',
#   'npxG': '2.8224958293139935',
#   'xGChain': '14.065670179203153',
#   'xGBuildup': '10.72426306270063'},
#  {'id': '499',
#   'player_name': 'Mesut Özil',
#   'games': '26',
#   'time': '2166',
#   'goals': '4',
#   'xG': '4.391980981454253',
#   'assists': '8',
#   'xA': '9.12884728424251',
#   'shots': '39',
#   'key_passes': '84',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal',
#   'npg': '4',
#   'npxG': '4.391980981454253',
#   'xGChain': '21.609493847936392',
#   'xGBuildup': '14.73346976004541'},
#  {'id': '533',
#   'player_name': 'Mark Noble',
#   'games': '29',
#   'time': '2411',
#   'goals': '4',
#   'xG': '2.278947896324098',
#   'assists': '0',
#   'xA': '1.809672282077372',
#   'shots': '15',
#   'key_passes': '20',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'West Ham',
#   'npg': '2',
#   'npxG': '0.7566102212294936',
#   'xGChain': '6.650566884316504',
#   'xGBuildup': '4.33457977604121'},
#  {'id': '611',
#   'player_name': 'Nicolás Otamendi',
#   'games': '34',
#   'time': '2975',
#   'goals': '4',
#   'xG': '3.190081411972642',
#   'assists': '0',
#   'xA': '1.1602246025577188',
#   'shots': '32',
#   'key_passes': '12',
#   'yellow_cards': '9',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester City',
#   'npg': '4',
#   'npxG': '3.190081411972642',
#   'xGChain': '19.018253933638334',
#   'xGBuildup': '17.79739197716117'},
#  {'id': '628',
#   'player_name': 'Chris Smalling',
#   'games': '29',
#   'time': '2533',
#   'goals': '4',
#   'xG': '2.170547891408205',
#   'assists': '0',
#   'xA': '0.176917914301157',
#   'shots': '13',
#   'key_passes': '2',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester United',
#   'npg': '4',
#   'npxG': '2.170547891408205',
#   'xGChain': '5.587086817249656',
#   'xGBuildup': '5.350759183987975'},
#  {'id': '630',
#   'player_name': 'Marouane Fellaini',
#   'games': '16',
#   'time': '601',
#   'goals': '4',
#   'xG': '2.7319894060492516',
#   'assists': '0',
#   'xA': '0.1612557740882039',
#   'shots': '10',
#   'key_passes': '5',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Manchester United',
#   'npg': '4',
#   'npxG': '2.7319894060492516',
#   'xGChain': '3.959240186959505',
#   'xGBuildup': '2.3747190637513995'},
#  {'id': '687',
#   'player_name': 'Pedro',
#   'games': '31',
#   'time': '1523',
#   'goals': '4',
#   'xG': '3.599893154576421',
#   'assists': '2',
#   'xA': '1.6855354961007833',
#   'shots': '56',
#   'key_passes': '26',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Chelsea',
#   'npg': '4',
#   'npxG': '3.599893154576421',
#   'xGChain': '6.591060146689415',
#   'xGBuildup': '2.555188376456499'},
#  {'id': '714',
#   'player_name': 'Gylfi Sigurdsson',
#   'games': '27',
#   'time': '2265',
#   'goals': '4',
#   'xG': '3.187053117901087',
#   'assists': '3',
#   'xA': '3.746338976547122',
#   'shots': '39',
#   'key_passes': '36',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Everton',
#   'npg': '4',
#   'npxG': '3.187053117901087',
#   'xGChain': '8.545136949047446',
#   'xGBuildup': '3.432769887149334'},
#  {'id': '735',
#   'player_name': 'Jermain Defoe',
#   'games': '24',
#   'time': '1074',
#   'goals': '4',
#   'xG': '4.541553013026714',
#   'assists': '1',
#   'xA': '1.017569174990058',
#   'shots': '27',
#   'key_passes': '13',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Bournemouth',
#   'npg': '4',
#   'npxG': '4.541553013026714',
#   'xGChain': '4.455103533342481',
#   'xGBuildup': '0.24524981901049614'},
#  {'id': '866',
#   'player_name': 'Joselu',
#   'games': '30',
#   'time': '1730',
#   'goals': '4',
#   'xG': '6.360850157216191',
#   'assists': '1',
#   'xA': '1.2996565690264106',
#   'shots': '47',
#   'key_passes': '16',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Newcastle United',
#   'npg': '4',
#   'npxG': '5.599681349471211',
#   'xGChain': '7.894001133739948',
#   'xGBuildup': '2.6755166612565517'},
#  {'id': '1661',
#   'player_name': 'Sam Vokes',
#   'games': '29',
#   'time': '953',
#   'goals': '4',
#   'xG': '3.006058517843485',
#   'assists': '1',
#   'xA': '1.1516352770850062',
#   'shots': '30',
#   'key_passes': '9',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Burnley',
#   'npg': '4',
#   'npxG': '3.006058517843485',
#   'xGChain': '2.201550272293389',
#   'xGBuildup': '0.07625440880656242'},
#  {'id': '5555',
#   'player_name': 'Dominic Calvert-Lewin',
#   'games': '32',
#   'time': '1861',
#   'goals': '4',
#   'xG': '5.436775926500559',
#   'assists': '6',
#   'xA': '3.0651565305888653',
#   'shots': '42',
#   'key_passes': '20',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Everton',
#   'npg': '4',
#   'npxG': '5.436775926500559',
#   'xGChain': '9.517184633761644',
#   'xGBuildup': '3.41016012057662'},
#  {'id': '6033',
#   'player_name': 'Aaron Mooy',
#   'games': '36',
#   'time': '3077',
#   'goals': '4',
#   'xG': '2.863141803070903',
#   'assists': '3',
#   'xA': '4.150494754314423',
#   'shots': '29',
#   'key_passes': '50',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Huddersfield',
#   'npg': '3',
#   'npxG': '2.101972905918956',
#   'xGChain': '7.695051764138043',
#   'xGBuildup': '4.615361374802887'},
#  {'id': '317',
#   'player_name': 'Henrikh Mkhitaryan',
#   'games': '26',
#   'time': '1735',
#   'goals': '3',
#   'xG': '2.473670184612274',
#   'assists': '9',
#   'xA': '6.7716568894684315',
#   'shots': '36',
#   'key_passes': '44',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal,Manchester United',
#   'npg': '3',
#   'npxG': '2.473670184612274',
#   'xGChain': '14.398008842021227',
#   'xGBuildup': '7.172531260177493'},
#  {'id': '461',
#   'player_name': 'Matt Ritchie',
#   'games': '35',
#   'time': '2822',
#   'goals': '3',
#   'xG': '3.193385612219572',
#   'assists': '5',
#   'xA': '6.588133158162236',
#   'shots': '58',
#   'key_passes': '53',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Newcastle United',
#   'npg': '3',
#   'npxG': '3.193385612219572',
#   'xGChain': '10.309624302200973',
#   'xGBuildup': '5.674191934987903'},
#  {'id': '500',
#   'player_name': 'Alex Iwobi',
#   'games': '26',
#   'time': '1873',
#   'goals': '3',
#   'xG': '4.13238912820816',
#   'assists': '5',
#   'xA': '3.4858018020167947',
#   'shots': '45',
#   'key_passes': '36',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '4.13238912820816',
#   'xGChain': '17.1490321457386',
#   'xGBuildup': '11.719522949308157'},
#  {'id': '503',
#   'player_name': 'Theo Walcott',
#   'games': '20',
#   'time': '1207',
#   'goals': '3',
#   'xG': '3.152715053409338',
#   'assists': '3',
#   'xA': '3.027757111005485',
#   'shots': '19',
#   'key_passes': '13',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Arsenal,Everton',
#   'npg': '3',
#   'npxG': '3.152715053409338',
#   'xGChain': '6.348237079568207',
#   'xGBuildup': '2.443506656214595'},
#  {'id': '520',
#   'player_name': 'Bakary Sako',
#   'games': '16',
#   'time': '446',
#   'goals': '3',
#   'xG': '2.270359752699733',
#   'assists': '0',
#   'xA': '0.7738894745707512',
#   'shots': '17',
#   'key_passes': '7',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Crystal Palace',
#   'npg': '3',
#   'npxG': '2.270359752699733',
#   'xGChain': '2.393583443015814',
#   'xGBuildup': '0.5047074863687158'},
#  {'id': '530',
#   'player_name': 'James Tomkins',
#   'games': '28',
#   'time': '2386',
#   'goals': '3',
#   'xG': '2.7092991154640913',
#   'assists': '0',
#   'xA': '0.07209452241659164',
#   'shots': '22',
#   'key_passes': '1',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Crystal Palace',
#   'npg': '3',
#   'npxG': '2.7092991154640913',
#   'xGChain': '2.036889584735036',
#   'xGBuildup': '1.9920928459614515'},
#  {'id': '531',
#   'player_name': 'Michail Antonio',
#   'games': '21',
#   'time': '1347',
#   'goals': '3',
#   'xG': '2.0091192554682493',
#   'assists': '1',
#   'xA': '0.9207208165898919',
#   'shots': '34',
#   'key_passes': '14',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'West Ham',
#   'npg': '3',
#   'npxG': '2.0091192554682493',
#   'xGChain': '3.456526911817491',
#   'xGBuildup': '1.1478512324392796'},
#  {'id': '537',
#   'player_name': 'Andy Carroll',
#   'games': '16',
#   'time': '739',
#   'goals': '3',
#   'xG': '1.5721641201525927',
#   'assists': '0',
#   'xA': '0.5253239311277866',
#   'shots': '28',
#   'key_passes': '7',
#   'yellow_cards': '5',
#   'red_cards': '1',
#   'position': 'F S',
#   'team_title': 'West Ham',
#   'npg': '3',
#   'npxG': '1.5721641201525927',
#   'xGChain': '3.6913193352520466',
#   'xGBuildup': '2.298567174002528'},
#  {'id': '541',
#   'player_name': 'Victor Moses',
#   'games': '28',
#   'time': '2128',
#   'goals': '3',
#   'xG': '3.0845435988157988',
#   'assists': '3',
#   'xA': '2.6375404447317123',
#   'shots': '35',
#   'key_passes': '20',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Chelsea',
#   'npg': '3',
#   'npxG': '3.0845435988157988',
#   'xGChain': '9.64580113440752',
#   'xGBuildup': '5.043449763208628'},
#  {'id': '554',
#   'player_name': 'Juan Mata',
#   'games': '28',
#   'time': '1942',
#   'goals': '3',
#   'xG': '3.8096582693979144',
#   'assists': '5',
#   'xA': '4.73291477933526',
#   'shots': '28',
#   'key_passes': '51',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '3.8096582693979144',
#   'xGChain': '14.234998783096671',
#   'xGBuildup': '8.80370701663196'},
#  {'id': '604',
#   'player_name': 'Emre Can',
#   'games': '26',
#   'time': '2099',
#   'goals': '3',
#   'xG': '1.5114367678761482',
#   'assists': '4',
#   'xA': '3.046363638713956',
#   'shots': '27',
#   'key_passes': '24',
#   'yellow_cards': '8',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Liverpool',
#   'npg': '3',
#   'npxG': '1.5114367678761482',
#   'xGChain': '15.16836054250598',
#   'xGBuildup': '12.476845782250166'},
#  {'id': '606',
#   'player_name': 'Christian Benteke',
#   'games': '31',
#   'time': '2224',
#   'goals': '3',
#   'xG': '11.166231762617826',
#   'assists': '5',
#   'xA': '3.276504169218242',
#   'shots': '59',
#   'key_passes': '27',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'F S',
#   'team_title': 'Crystal Palace',
#   'npg': '2',
#   'npxG': '9.643894027918577',
#   'xGChain': '12.039164207875729',
#   'xGBuildup': '3.1662193890661'},
#  {'id': '620',
#   'player_name': 'Kelechi Iheanacho',
#   'games': '21',
#   'time': '809',
#   'goals': '3',
#   'xG': '4.825845109298825',
#   'assists': '3',
#   'xA': '2.0846437010914087',
#   'shots': '29',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Leicester',
#   'npg': '3',
#   'npxG': '4.825845109298825',
#   'xGChain': '5.066860610619187',
#   'xGBuildup': '0.6976034194231033'},
#  {'id': '627',
#   'player_name': 'Antonio Valencia',
#   'games': '31',
#   'time': '2746',
#   'goals': '3',
#   'xG': '0.5440769195556641',
#   'assists': '1',
#   'xA': '1.4601692892611027',
#   'shots': '16',
#   'key_passes': '23',
#   'yellow_cards': '7',
#   'red_cards': '0',
#   'position': 'D M',
#   'team_title': 'Manchester United',
#   'npg': '3',
#   'npxG': '0.5440769195556641',
#   'xGChain': '9.933676397427917',
#   'xGBuildup': '8.8214799631387'},
#  {'id': '713',
#   'player_name': 'André Ayew',
#   'games': '30',
#   'time': '1859',
#   'goals': '3',
#   'xG': '4.747821493074298',
#   'assists': '4',
#   'xA': '1.5065012574195862',
#   'shots': '26',
#   'key_passes': '16',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'F M S',
#   'team_title': 'Swansea,West Ham',
#   'npg': '3',
#   'npxG': '3.986652595922351',
#   'xGChain': '5.011983007192612',
#   'xGBuildup': '1.8361061811447144'},
#  {'id': '762',
#   'player_name': 'Demarai Gray',
#   'games': '35',
#   'time': '1680',
#   'goals': '3',
#   'xG': '2.6410227809101343',
#   'assists': '1',
#   'xA': '3.2531555332243443',
#   'shots': '36',
#   'key_passes': '27',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester',
#   'npg': '3',
#   'npxG': '2.6410227809101343',
#   'xGChain': '8.21831576153636',
#   'xGBuildup': '3.4607087997719646'},
#  {'id': '764',
#   'player_name': 'Daryl Janmaat',
#   'games': '23',
#   'time': '1823',
#   'goals': '3',
#   'xG': '1.650841942988336',
#   'assists': '0',
#   'xA': '0.9912619115784764',
#   'shots': '24',
#   'key_passes': '12',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Watford',
#   'npg': '3',
#   'npxG': '1.650841942988336',
#   'xGChain': '4.680951441638172',
#   'xGBuildup': '3.0537470430135727'},
#  {'id': '766',
#   'player_name': 'Jamaal Lascelles',
#   'games': '33',
#   'time': '2929',
#   'goals': '3',
#   'xG': '1.509770625270903',
#   'assists': '0',
#   'xA': '0.36995767429471016',
#   'shots': '12',
#   'key_passes': '6',
#   'yellow_cards': '5',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Newcastle United',
#   'npg': '3',
#   'npxG': '1.509770625270903',
#   'xGChain': '3.3113895878195763',
#   'xGBuildup': '3.2026653848588467'},
#  {'id': '784',
#   'player_name': 'Andy King',
#   'games': '22',
#   'time': '1264',
#   'goals': '3',
#   'xG': '1.5606138529255986',
#   'assists': '0',
#   'xA': '0.25664781779050827',
#   'shots': '14',
#   'key_passes': '6',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester,Swansea',
#   'npg': '3',
#   'npxG': '1.5606138529255986',
#   'xGChain': '2.1329348580911756',
#   'xGBuildup': '1.552365998737514'},
#  {'id': '843',
#   'player_name': 'James Ward-Prowse',
#   'games': '30',
#   'time': '1714',
#   'goals': '3',
#   'xG': '2.313723925501108',
#   'assists': '3',
#   'xA': '3.9457491729408503',
#   'shots': '28',
#   'key_passes': '36',
#   'yellow_cards': '4',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Southampton',
#   'npg': '3',
#   'npxG': '2.313723925501108',
#   'xGChain': '5.334738714620471',
#   'xGBuildup': '3.21634188760072'},
#  {'id': '883',
#   'player_name': 'Steven Davis',
#   'games': '23',
#   'time': '1529',
#   'goals': '3',
#   'xG': '1.2866387125104666',
#   'assists': '0',
#   'xA': '1.1766847083345056',
#   'shots': '13',
#   'key_passes': '18',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Southampton',
#   'npg': '3',
#   'npxG': '1.2866387125104666',
#   'xGChain': '5.108900390565395',
#   'xGBuildup': '3.5151044093072414'},
#  {'id': '966',
#   'player_name': 'Alex Oxlade-Chamberlain',
#   'games': '35',
#   'time': '1705',
#   'goals': '3',
#   'xG': '2.5996209820732474',
#   'assists': '7',
#   'xA': '4.965171821415424',
#   'shots': '47',
#   'key_passes': '38',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'D F M S',
#   'team_title': 'Arsenal,Liverpool',
#   'npg': '3',
#   'npxG': '2.5996209820732474',
#   'xGChain': '11.884014029055834',
#   'xGBuildup': '6.252592153847218'},
#  {'id': '1690',
#   'player_name': 'Sam Clucas',
#   'games': '29',
#   'time': '2043',
#   'goals': '3',
#   'xG': '1.939705403521657',
#   'assists': '1',
#   'xA': '0.9887255234643817',
#   'shots': '18',
#   'key_passes': '15',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D M S',
#   'team_title': 'Swansea',
#   'npg': '3',
#   'npxG': '1.939705403521657',
#   'xGChain': '4.251216282136738',
#   'xGBuildup': '2.113673910498619'},
#  {'id': '1699',
#   'player_name': 'Shkodran Mustafi',
#   'games': '27',
#   'time': '2272',
#   'goals': '3',
#   'xG': '0.7174240592867136',
#   'assists': '1',
#   'xA': '1.895219400525093',
#   'shots': '13',
#   'key_passes': '7',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Arsenal',
#   'npg': '3',
#   'npxG': '0.7174240592867136',
#   'xGChain': '9.468940455466509',
#   'xGBuildup': '9.41240644082427'},
#  {'id': '2065',
#   'player_name': 'Vicente Iborra',
#   'games': '19',
#   'time': '1424',
#   'goals': '3',
#   'xG': '1.5937974713742733',
#   'assists': '0',
#   'xA': '0.48453015089035034',
#   'shots': '14',
#   'key_passes': '8',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester',
# ...
#   'xGBuildup': '4.563934212550521'},
#  {'id': '6051',
#   'player_name': 'Dale Stephens',
#   'games': '36',
#   'time': '3240',
#   'goals': '0',
#   'xG': '0.7653933931142092',
#   'assists': '3',
#   'xA': '2.1089132223278284',
#   'shots': '19',
#   'key_passes': '17',
#   'yellow_cards': '6',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.7653933931142092',
#   'xGChain': '7.675400568172336',
#   'xGBuildup': '5.764904314652085'},
#  {'id': '6052',
#   'player_name': 'Jamie Murphy',
#   'games': '4',
#   'time': '166',
#   'goals': '0',
#   'xG': '0.058501455932855606',
#   'assists': '0',
#   'xA': '0.00925317220389843',
#   'shots': '1',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.058501455932855606',
#   'xGChain': '0.06775462627410889',
#   'xGBuildup': '0.00925317220389843'},
#  {'id': '6054',
#   'player_name': 'Ederson',
#   'games': '36',
#   'time': '3195',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.03262508288025856',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Manchester City',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '8.560575978830457',
#   'xGBuildup': '8.527950899675488'},
#  {'id': '6055',
#   'player_name': 'Phil Foden',
#   'games': '5',
#   'time': '41',
#   'goals': '0',
#   'xG': '0',
#   'assists': '1',
#   'xA': '0.48960746824741364',
#   'shots': '0',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester City',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.8641108125448227',
#   'xGBuildup': '0.37450334429740906'},
#  {'id': '6067',
#   'player_name': 'Terence Kongolo',
#   'games': '13',
#   'time': '1043',
#   'goals': '0',
#   'xG': '0.1555066779255867',
#   'assists': '0',
#   'xA': '0.167850561439991',
#   'shots': '2',
#   'key_passes': '3',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Huddersfield',
#   'npg': '0',
#   'npxG': '0.1555066779255867',
#   'xGChain': '1.4275773176923394',
#   'xGBuildup': '1.259726750664413'},
#  {'id': '6080',
#   'player_name': 'Victor Lindelöf',
#   'games': '17',
#   'time': '1280',
#   'goals': '0',
#   'xG': '0.012279543094336987',
#   'assists': '0',
#   'xA': '0.2188112735748291',
#   'shots': '1',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Manchester United',
#   'npg': '0',
#   'npxG': '0.012279543094336987',
#   'xGChain': '3.0813139472156763',
#   'xGBuildup': '2.862502673640847'},
#  {'id': '6105',
#   'player_name': 'Gaëtan Bong',
#   'games': '25',
#   'time': '2243',
#   'goals': '0',
#   'xG': '0.05226822569966316',
#   'assists': '0',
#   'xA': '0.5265474775806069',
#   'shots': '4',
#   'key_passes': '9',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.05226822569966316',
#   'xGChain': '2.6286782575771213',
#   'xGBuildup': '2.277553342282772'},
#  {'id': '6249',
#   'player_name': 'Davinson Sánchez',
#   'games': '31',
#   'time': '2535',
#   'goals': '0',
#   'xG': '0.5712868580594659',
#   'assists': '0',
#   'xA': '0.12518768198788166',
#   'shots': '9',
#   'key_passes': '4',
#   'yellow_cards': '1',
#   'red_cards': '1',
#   'position': 'D S',
#   'team_title': 'Tottenham',
#   'npg': '0',
#   'npxG': '0.5712868580594659',
#   'xGChain': '7.701586965471506',
#   'xGBuildup': '7.640087593346834'},
#  {'id': '6276',
#   'player_name': 'Nikola Vlasic',
#   'games': '12',
#   'time': '572',
#   'goals': '0',
#   'xG': '0.32545805163681507',
#   'assists': '0',
#   'xA': '0.8369456082582474',
#   'shots': '5',
#   'key_passes': '12',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0.32545805163681507',
#   'xGChain': '1.8046257346868515',
#   'xGBuildup': '0.8781686592847109'},
#  {'id': '6283',
#   'player_name': 'Levi Lumeka',
#   'games': '1',
#   'time': '22',
#   'goals': '0',
#   'xG': '0.07800616323947906',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Crystal Palace',
#   'npg': '0',
#   'npxG': '0.07800616323947906',
#   'xGChain': '0.07800616323947906',
#   'xGBuildup': '0'},
#  {'id': '6296',
#   'player_name': 'Abdelhamid Sabiri',
#   'games': '5',
#   'time': '215',
#   'goals': '0',
#   'xG': '0.240287309512496',
#   'assists': '1',
#   'xA': '0.1478404998779297',
#   'shots': '5',
#   'key_passes': '2',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Huddersfield',
#   'npg': '0',
#   'npxG': '0.240287309512496',
#   'xGChain': '0.3436395153403282',
#   'xGBuildup': '0.12604163587093353'},
#  {'id': '6299',
#   'player_name': 'Connor Goldson',
#   'games': '3',
#   'time': '198',
#   'goals': '0',
#   'xG': '0.26348188519477844',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.26348188519477844',
#   'xGChain': '0.3618545141071081',
#   'xGBuildup': '0.3618545141071081'},
#  {'id': '6301',
#   'player_name': 'Jonathan Hogg',
#   'games': '30',
#   'time': '2425',
#   'goals': '0',
#   'xG': '0.32147238217294216',
#   'assists': '0',
#   'xA': '0.5861909277737141',
#   'shots': '11',
#   'key_passes': '9',
#   'yellow_cards': '8',
#   'red_cards': '1',
#   'position': 'M S',
#   'team_title': 'Huddersfield',
#   'npg': '0',
#   'npxG': '0.32147238217294216',
#   'xGChain': '4.865368423052132',
#   'xGBuildup': '4.23953568097204'},
#  {'id': '6303',
#   'player_name': 'Marvin Zeegelaar',
#   'games': '12',
#   'time': '995',
#   'goals': '0',
#   'xG': '0',
#   'assists': '1',
#   'xA': '0.8659056201577187',
#   'shots': '0',
#   'key_passes': '7',
#   'yellow_cards': '4',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Watford',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '2.392251036129892',
#   'xGBuildup': '1.8178213881328702'},
#  {'id': '6328',
#   'player_name': 'Dean Whitehead',
#   'games': '4',
#   'time': '63',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Huddersfield',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.06561291590332985',
#   'xGBuildup': '0.06561291590332985'},
#  {'id': '6344',
#   'player_name': 'Martin Cranie',
#   'games': '3',
#   'time': '184',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D S',
#   'team_title': 'Huddersfield',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.15702663362026215',
#   'xGBuildup': '0.15702663362026215'},
#  {'id': '6369',
#   'player_name': 'Ethan Ampadu',
#   'games': '1',
#   'time': '9',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '6384',
#   'player_name': 'Beni Baningime',
#   'games': '8',
#   'time': '185',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Everton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '1.1460985392332077',
#   'xGBuildup': '1.1460985392332077'},
#  {'id': '6389',
#   'player_name': 'Nahki Wells',
#   'games': '9',
#   'time': '37',
#   'goals': '0',
#   'xG': '0.6687097437679768',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0.6687097437679768',
#   'xGChain': '0.6905566640198231',
#   'xGBuildup': '0.021846920251846313'},
#  {'id': '6409',
#   'player_name': 'Beram Kayal',
#   'games': '19',
#   'time': '731',
#   'goals': '0',
#   'xG': '0.34128111600875854',
#   'assists': '0',
#   'xA': '0.45063072070479393',
#   'shots': '4',
#   'key_passes': '11',
#   'yellow_cards': '2',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0.34128111600875854',
#   'xGChain': '1.0508340448141098',
#   'xGBuildup': '0.43324288353323936'},
#  {'id': '6410',
#   'player_name': 'Jack Simpson',
#   'games': '1',
#   'time': '74',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'D',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '6418',
#   'player_name': 'Hamza Choudhury',
#   'games': '8',
#   'time': '376',
#   'goals': '0',
#   'xG': '0.03584326710551977',
#   'assists': '1',
#   'xA': '0.21633946895599365',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '1',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester',
#   'npg': '0',
#   'npxG': '0.03584326710551977',
#   'xGChain': '1.093845408409834',
#   'xGBuildup': '0.8775059394538403'},
#  {'id': '6421',
#   'player_name': 'Brahim Diaz',
#   'games': '5',
#   'time': '40',
#   'goals': '0',
#   'xG': '0.4937528669834137',
#   'assists': '0',
#   'xA': '0',
#   'shots': '3',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester City',
#   'npg': '0',
#   'npxG': '0.4937528669834137',
#   'xGChain': '0.5121959801763296',
#   'xGBuildup': '0.018443113192915916'},
#  {'id': '6430',
#   'player_name': 'Sam Baldock',
#   'games': '2',
#   'time': '28',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Brighton',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.10130543261766434',
#   'xGBuildup': '0.10130543261766434'},
#  {'id': '6456',
#   'player_name': 'Callum Hudson-Odoi',
#   'games': '2',
#   'time': '25',
#   'goals': '0',
#   'xG': '0.10454526543617249',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Chelsea',
#   'npg': '0',
#   'npxG': '0.10454526543617249',
#   'xGChain': '0.20239269733428955',
#   'xGBuildup': '0.09784743189811707'},
#  {'id': '6457',
#   'player_name': 'Emerson Hyndman',
#   'games': '1',
#   'time': '60',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0.022522175684571266',
#   'shots': '0',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Bournemouth',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.017591072246432304',
#   'xGBuildup': '0.017591072246432304'},
#  {'id': '6464',
#   'player_name': 'Adrien Silva',
#   'games': '12',
#   'time': '765',
#   'goals': '0',
#   'xG': '0.24159271083772182',
#   'assists': '1',
#   'xA': '0.8903077002614737',
#   'shots': '11',
#   'key_passes': '6',
#   'yellow_cards': '3',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Leicester',
#   'npg': '0',
#   'npxG': '0.24159271083772182',
#   'xGChain': '4.712758015841246',
#   'xGBuildup': '3.692299570888281'},
#  {'id': '6482',
#   'player_name': 'Eddie Nketiah',
#   'games': '3',
#   'time': '11',
#   'goals': '0',
#   'xG': '0.0814666673541069',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0.0814666673541069',
#   'xGChain': '0.0814666673541069',
#   'xGBuildup': '0'},
#  {'id': '6492',
#   'player_name': 'Reiss Nelson',
#   'games': '3',
#   'time': '147',
#   'goals': '0',
#   'xG': '0.06884970515966415',
#   'assists': '0',
#   'xA': '0.03446457162499428',
#   'shots': '2',
#   'key_passes': '1',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0.06884970515966415',
#   'xGChain': '0.8568241000175476',
#   'xGBuildup': '0.7784193158149719'},
#  {'id': '6504',
#   'player_name': 'Michael Obafemi',
#   'games': '1',
#   'time': '7',
#   'goals': '0',
#   'xG': '0.5450024604797363',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Southampton',
#   'npg': '0',
#   'npxG': '0.5450024604797363',
#   'xGChain': '0.5450024604797363',
#   'xGBuildup': '0'},
#  {'id': '6526',
#   'player_name': 'Jordan Hugill',
#   'games': '3',
#   'time': '13',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'West Ham',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '6531',
#   'player_name': 'Alexander Sørloth',
#   'games': '4',
#   'time': '360',
#   'goals': '0',
#   'xG': '0.5928351525217295',
#   'assists': '0',
#   'xA': '0.3902565613389015',
#   'shots': '7',
#   'key_passes': '6',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'F M',
#   'team_title': 'Crystal Palace',
#   'npg': '0',
#   'npxG': '0.5928351525217295',
#   'xGChain': '1.5126995090395212',
#   'xGBuildup': '0.7650693506002426'},
#  {'id': '6532',
#   'player_name': 'Martin Dubravka',
#   'games': '12',
#   'time': '1080',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'GK',
#   'team_title': 'Newcastle United',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.5088649336248636',
#   'xGBuildup': '0.5088649336248636'},
#  {'id': '6544',
#   'player_name': 'Lukas Nmecha',
#   'games': '2',
#   'time': '8',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Manchester City',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'},
#  {'id': '6561',
#   'player_name': 'Tyrese Campbell',
#   'games': '4',
#   'time': '66',
#   'goals': '0',
#   'xG': '0.1487518772482872',
#   'assists': '0',
#   'xA': '0',
#   'shots': '2',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Stoke',
#   'npg': '0',
#   'npxG': '0.1487518772482872',
#   'xGChain': '0.07220914959907532',
#   'xGBuildup': '0'},
#  {'id': '6630',
#   'player_name': 'Joe Willock',
#   'games': '2',
#   'time': '82',
#   'goals': '0',
#   'xG': '0.1126566231250763',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M S',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0.1126566231250763',
#   'xGChain': '0.46951115131378174',
#   'xGBuildup': '0.35685452818870544'},
#  {'id': '6657',
#   'player_name': 'Lasse Sorenson',
#   'games': '1',
#   'time': '78',
#   'goals': '0',
#   'xG': '0',
#   'assists': '1',
#   'xA': '0.36800387501716614',
#   'shots': '0',
#   'key_passes': '2',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'M',
#   'team_title': 'Stoke',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.06694087386131287',
#   'xGBuildup': '0.04735318198800087'},
#  {'id': '6681',
#   'player_name': 'Harvey Barnes',
#   'games': '3',
#   'time': '5',
#   'goals': '0',
#   'xG': '0.05426165834069252',
#   'assists': '0',
#   'xA': '0',
#   'shots': '1',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Leicester',
#   'npg': '0',
#   'npxG': '0.05426165834069252',
#   'xGChain': '0.1033472940325737',
#   'xGBuildup': '0.1033472940325737'},
#  {'id': '6722',
#   'player_name': 'Konstantinos Mavropanos',
#   'games': '3',
#   'time': '194',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '1',
#   'position': 'D',
#   'team_title': 'Arsenal',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0.9823358356952667',
#   'xGBuildup': '0.9823358356952667'},
#  {'id': '6756',
#   'player_name': 'Dwight McNeil',
#   'games': '1',
#   'time': '1',
#   'goals': '0',
#   'xG': '0',
#   'assists': '0',
#   'xA': '0',
#   'shots': '0',
#   'key_passes': '0',
#   'yellow_cards': '0',
#   'red_cards': '0',
#   'position': 'S',
#   'team_title': 'Burnley',
#   'npg': '0',
#   'npxG': '0',
#   'xGChain': '0',
#   'xGBuildup': '0'}]

# %%
# !jupyter nbconvert --to html baseline.ipynb
# Out:
# [NbConvertApp] Converting notebook baseline.ipynb to html
# [NbConvertApp] Writing 352634 bytes to baseline.html

# %%
player_df.loc[:, 'id'].unique().shape
# Out:
# (38,)

# %%
player_df.to_csv('../../../data/Chelsea_player_2018.csv', index = None)
